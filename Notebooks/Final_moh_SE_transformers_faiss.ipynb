# %%
import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                              _: 43.9 MiB
#                             __: 43.9 MiB
#                    docs_df_SE4: 43.9 MiB
#                             _9: 43.9 MiB
#                            _10: 43.9 MiB
#                     embeddings: 14.9 MiB
#            SentenceTransformer:  904.0 B
#                           _i12:  587.0 B
#                            _i4:  422.0 B
#                            _i5:  422.0 B

# %% [markdown]
# - a software system to bring out information of web
#
# - smart search engines can be considered unsupervised learning approaches, due to the nature of clustering related information without such label in hand
#
# - Search Engines have evolved **from a text input and output service to** an experience that cuts across voice, video, documents, and conversations
#
#
# - an **infinite problem** to solve
#
#
# - **related** to information retrieval, language understanding
#
#
# - the **value that an effective search tool can bring to a business is enormous**; a key piece of intellectual property. Often a search bar is the main interface between customers and the business.
#     - create a competitive advantage by delivering an improved user experience.

# %% [markdown]
# search engine popular approaches:
# - manual implementation with dataframe + tf-idf
# - Elastic Search + BM25
# - BM25 + Azure Cognitive Search

# %% [markdown]
# Requirements:
# - Search index for storing each document, reflecting relevant information and up to date information
#     - data can be reorganized by date (suggestion)
# - Query understanding
#     - takes sentence and preprocessed data information **directly without much context**
#     - we can extract words or tokens from the query to match **article_type** (suggestion)
#         - query to match tags (done)
#     - we can filter the search by either blog or News (suggestion)
#         - or add multiple results available (blog, News, or both)
#     - BM25 + Azure Cognitive search
# - Query ranking
#     - by consine similarity

# %% [markdown]
# ## 1- Library and Data Imports

# %%
# Used to import data from S3.
import pandas as pd

# Used to create the dense document vectors.
import torch
from sentence_transformers import SentenceTransformer, util

# Used to create and store the Faiss index.
# import faiss
import numpy as np
# import pickle

# Used to do vector searches and display the results.
# from vector_engine.utils import vector_search, id2details

# %%
docs_df_SE4 = pd.read_csv('../Data/processed/SE_data4.csv')

# %%
# Instantiate the sentence-level DistilBERT
model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens') 
# model = SentenceTransformer('all-MiniLM-L6-v2') 
# model = SentenceTransformer("multi-qa/-MiniLM-L6-cos-v1") 
# model = SentenceTransformer("ZeyadAhmed/AraElectra-Arabic-SQuADv2-QA") 

# Check if CUDA is available ans switch to GPU
if torch.cuda.is_available():
    model = model.to(torch.device("cuda"))
print(model.device)
# Out:
# cuda:0

# %%
# Convert abstracts to vectors
embeddings = model.encode(docs_df_SE4.content_clean.to_list(), show_progress_bar=True)
# Out:
# Batches: 100%|███████████████████████████████████████████████████████████████████████| 159/159 [00:18<00:00,  8.81it/s]

# %%
query = 'نبوي'.split()
print(query)
query_encoded = model.encode(query, show_progress_bar=True)
query_encoded = np.reshape(np.mean(query_encoded, axis=0), (-1, 1))
# Out:
# ['نبوي']
# Batches: 100%|███████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 41.67it/s]

# %%
query_encoded.shape, embeddings.shape
# Out:
# ((768, 1), (5084, 768))

# %%
cosine_scores = util.cos_sim(embeddings, query_encoded.T)
cosine_scores_ids = list(enumerate(np.reshape(cosine_scores, (cosine_scores.shape[0]))))
cosine_scores_sorted = sorted(cosine_scores_ids, key=lambda x: x[1], reverse=True) 

for id_, score in cosine_scores_sorted[:10]:
#     print(round(score, 2))
    print(docs_df_SE4.content_clean.values[id_])
    print(docs_df_SE4.url.values[id_])
# Out:
# حوار كاتب إبراهيم غرايبه كتاب أردن ممكن
# https://husna.fm/%D9%85%D9%86-%D9%85%D9%83%D8%AA%D8%A8%D8%A9-%D8%A7%D9%84%D8%A8%D9%84%D8%AF/%D8%AD%D9%88%D8%A7%D8%B1-%D9%85%D8%B9-%D8%A7%D9%84%D9%83%D8%A7%D8%AA%D8%A8-%D8%A5%D8%A8%D8%B1%D8%A7%D9%87%D9%8A%D9%85-%D8%BA%D8%B1%D8%A7%D9%8A%D8%A8%D8%A9-%D8%AD%D9%88%D9%84-%D9%83%D8%AA%D8%A7%D8%A8%D9%87-%D8%A7%D9%84%D8%A3%D8%B1%D8%AF%D9%86-%D8%A7%D9%84%D9%85%D9%85%D9%83%D9%86
# حوار د يونس شناعه حديث سيره ذاتي عنوان شقاء سنه
# https://husna.fm/%D9%85%D9%86-%D9%85%D9%83%D8%AA%D8%A8%D8%A9-%D8%A7%D9%84%D8%A8%D9%84%D8%AF/%D8%AD%D9%88%D8%A7%D8%B1-%D9%85%D8%B9-%D8%AF%D9%8A%D9%88%D9%86%D8%B3-%D8%B4%D9%86%D8%A7%D8%B9%D8%A9%D8%8C-%D9%84%D9%84%D8%AD%D8%AF%D9%8A%D8%AB-%D8%AD%D9%88%D9%84-%D8%B3%D9%8A%D8%B1%D8%AA%D9%87-%D8%A7%D9%84%D8%B0%D8%A7%D8%AA%D9%8A%D9%87-%D8%A8%D8%B9%D9%86%D9%88%D8%A7%D9%86-%D8%B4%D9%82%D8%A7%D8%A1-%D8%A7%D9%84%D8%B3%D9%86%D9%8A%D9%86
# قصه ملك حارس عجوز ليل شديد ب رود
# https://husna.fm/%D9%85%D8%A7%D8%B0%D8%A7-%D9%84%D9%88%D8%9F/%D9%82%D8%B5%D8%A9-%D8%A7%D9%84%D9%85%D9%84%D9%83-%D9%85%D8%B9-%D8%A7%D9%84%D8%AD%D8%A7%D8%B1%D8%B3-%D8%A7%D9%84%D8%B9%D8%AC%D9%88%D8%B2-%D9%81%D9%8A-%D9%84%D9%8A%D9%84%D8%A9-%D8%B4%D8%AF%D9%8A%D8%AF%D8%A9-%D8%A7%D9%84%D8%A8%D8%B1%D9%88%D8%AF%D8%A9
# روايه اشتباك حوار كاتب حسين ياسين
# https://husna.fm/%D9%85%D9%86-%D9%85%D9%83%D8%AA%D8%A8%D8%A9-%D8%A7%D9%84%D8%A8%D9%84%D8%AF/%D8%B1%D9%88%D8%A7%D9%8A%D8%A9-%D8%A7%D8%B4%D8%AA%D8%A8%D8%A7%D9%83-%D8%AD%D9%88%D8%A7%D8%B1-%D9%85%D8%B9-%D8%A7%D9%84%D9%83%D8%A7%D8%AA%D8%A8-%D8%AD%D8%B3%D9%8A%D9%86-%D9%8A%D8%A7%D8%B3%D9%8A%D9%86
# ذكرى عاشر ثوره تونس عاش منعطف حاد تقرير بسيم صعوب قراءه آيه عمار الجعبري
# https://husna.fm/%D8%B9%D8%B1%D8%A8%D9%8A-%D9%88-%D8%AF%D9%88%D9%84%D9%8A/%D9%81%D9%8A-%D8%A7%D9%84%D8%B0%D9%83%D8%B1%D9%89-%D8%A7%D9%84%D8%B9%D8%A7%D8%B4%D8%B1%D8%A9-%D9%84%D9%84%D8%AB%D9%88%D8%B1%D8%A9%D8%8C-%D8%AA%D9%88%D9%86%D8%B3-%D8%AA%D8%B9%D9%8A%D8%B4-%D9%85%D9%86%D8%B9%D8%B7%D9%81%D9%8B%D8%A7-%D8%AD%D8%A7%D8%AF%D9%8B%D8%A7
# بقي حلم ثوره 25 ذكرى عاشر  تقرير بسيم صعوب
# https://husna.fm/%D8%B9%D8%B1%D8%A8%D9%8A-%D9%88-%D8%AF%D9%88%D9%84%D9%8A/%D9%85%D8%A7%D8%B0%D8%A7-%D8%A8%D9%82%D9%8A-%D9%85%D9%86-%D8%A3%D8%AD%D9%84%D8%A7%D9%85-%D8%AB%D9%88%D8%B1%D8%A9-25-%D9%8A%D9%86%D8%A7%D9%8A%D8%B1-%D9%81%D9%8A-%D8%B0%D9%83%D8%B1%D8%A7%D9%87%D8%A7-%D8%A7%D9%84%D8%B9%D8%A7%D8%B4%D8%B1%D8%A9%D8%9F
# أستضاف د سلامه بلوى كتاب تاريخ أمن معلومه حضاره إسلامي
# https://husna.fm/%D9%85%D9%86-%D9%85%D9%83%D8%AA%D8%A8%D8%A9-%D8%A7%D9%84%D8%A8%D9%84%D8%AF/%D8%A7%D8%B3%D8%AA%D8%B6%D8%A7%D9%81%D8%A9-%D8%AF%D8%B3%D9%84%D8%A7%D9%85%D8%A9-%D8%A7%D9%84%D8%A8%D9%84%D9%88%D9%8A-%D8%AD%D9%88%D9%84-%D9%83%D8%AA%D8%A7%D8%A8%D9%87-%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE-%D8%A3%D9%85%D9%86-%D8%A7%D9%84%D9%85%D8%B9%D9%84%D9%88%D9%85%D8%A7%D8%AA-%D9%81%D9%8A-%D8%A7%D9%84%D8%AD%D8%B6%D8%A7%D8%B1%D8%A9-%D8%A7%D9%84%D8%A5%D8%B3%D9%84%D8%A7%D9%85%D9%8A%D8%A9
# اعتقال شريف حسن زيد اسم الله آخر سبب أمني
# https://husna.fm/%D9%85%D8%AD%D9%84%D9%8A/%D8%A7%D8%B9%D8%AA%D9%82%D8%A7%D9%84-%D8%A7%D9%84%D8%B4%D8%B1%D9%8A%D9%81-%D8%AD%D8%B3%D9%86-%D8%A8%D9%86-%D8%B2%D9%8A%D8%AF-%D9%88%D8%A8%D8%A7%D8%B3%D9%85-%D8%B9%D9%88%D8%B6-%D8%A7%D9%84%D9%84%D9%87-%D9%88%D8%A2%D8%AE%D8%B1%D9%8A%D9%86-%D9%84%D8%A3%D8%B3%D8%A8%D8%A7%D8%A8-%D8%A3%D9%85%D9%86%D9%8A%D8%A9
# مواطن نشر غسيل تم تحويل مدعى عام
# https://husna.fm/%D9%85%D8%AD%D9%84%D9%8A/%D9%85%D9%88%D8%A7%D8%B7%D9%86-%D9%82%D8%A7%D9%85-%D8%A8%D9%86%D8%B4%D8%B1-%D8%A7%D9%84%D8%BA%D8%B3%D9%8A%D9%84%D8%8C-%D9%81%D8%AA%D9%85-%D8%AA%D8%AD%D9%88%D9%8A%D9%84%D9%87-%D9%84%D9%84%D9%85%D8%AF%D8%B9%D9%8A-%D8%A7%D9%84%D8%B9%D8%A7%D9%85
# حال قوي استقرار جوي تأثر مملكه
# https://husna.fm/%D9%85%D8%AD%D9%84%D9%8A/%D8%AD%D8%A7%D9%84%D8%A9-%D9%82%D9%88%D9%8A%D8%A9-%D9%85%D9%86-%D8%B9%D8%AF%D9%85-%D8%A7%D9%84%D8%A7%D8%B3%D8%AA%D9%82%D8%B1%D8%A7%D8%B1-%D8%A7%D9%84%D8%AC%D9%88%D9%8A-%D8%AA%D8%AA%D8%A3%D8%AB%D8%B1-%D8%A8%D9%87%D8%A7-%D8%A7%D9%84%D9%85%D9%85%D9%84%D9%83%D8%A9-%D8%A7%D9%84%D9%8A%D9%88%D9%85

# %%
embeddings.shape, query_encoded.shape
# Out:
# ((5084, 768), (768, 1))

# %%
result = np.dot(embeddings, query_encoded)
result_ids = list(enumerate(np.reshape(result, (result.shape[0]))))
result_ids_sorted = sorted(result_ids, key=lambda x: x[1], reverse=True)[200: 220]

# %%
for id_, score in result_ids_sorted:
    print(round(score, 2))
    print(docs_df_SE4.content_clean.values[id_])
#     print(docs_df_SE4.title.values[id_])
# Out:
# 110.68
# بترول وطني سرحان جفر حوى كميه قليل نفط مدير شركه بترول وطني محمد الخصاونه أن دراسه أول منطقه سرحان جفر أشار إلى تواجد كميه قليل نفط أضاف الخصاونه حسني أن عمر جيولوجي منطقه سرحان جفر أشبه إلى حد كبير عمر جيولوجي حقل ريش الخصاونه أن شركه هندي يونيفرسال انرجي قام عمل دراسه مسحيه منطقه سرحان جفر 2012 لافت إلى بدء تحليل دراسه حديث إذ ترتب حكومه أي كلف هذا دراسه أشار الخصاونه أن حقل أردني عمل آن حقل حمزه أزرق أنتج تراكميا إلى آن برميل نفط حقل ريش أنتج غايه آن ربع تريليون متر مكعب غاز تم آن دراسه منطقه سرحان جفر
# 110.68
# فصل تيار كهربائي منطقه شمال أعلن شركه كهرباء أربد نيه فصل تيار كهربائي اثنين منطقه محافظه إقليم شمال أربد جرش عجلون مفرق غايه صيانه تحسين جوده شبكه شركه بيان ل أن انقطاع شمل محافظ أربد منطقه صريح شرق محطه أبو عاشور جميع مشترك ثلاث فاز أن متوقع انقطاع ساعه تاسع صباح غايه ساعه حادي صباح إلى جانب منطقه ايدون جنوب مستشفى أربد تخصصي وقت متوقع انقطاع ساعه حادي صباح غايه واحد ظهر ما كان انقطاع منطقه ايدون جنوب دوار صحراء طريق قصر عواد ساعه واحد ظهر غايه ثالث عصر بين شركه أن فصل شمل محافظ جرش منطقه روضه بني هاشم جمع راشد زيود مجاور وقت متوقع انقطاع ساعه تاسع صباح غايه رابع مساء منطقه جمله شارع رئيسي قرب مسجد جرش دير شرقي وقت متوقع انقطاع ساعه تاسع صباح غايه خامس مساء أشار إلى شمول فصل محافظ عجلون منطقه بلد هاشمي وقت متوقع انقطاع ساعه تاسع صباح غايه رابع مساء منطقه ساخن صفصافه ساعه تاسع صباح غايه خامس مساء أوضح شركه أن فصل شمل محافظ مفرق منطقه محطه ضخ سلطه الخالديه 1 ساعه تاسع صباح غايه عاشر نصف صباح منطقه بئر سلطه 30 منطقه الخالديه ساعه ظهر غايه واحد نصف ظهر شمل فصل منطقه محول بئر محمد شاهين منطقه الخالديه ساعه واحد نصف ظهر غايه ثالث عصر منطقه بئر الكريدور مزرع جمال الحمايده مزرع خالد شديد ساعه تاسع صباح غايه ساعه رابع مساء أضاف إلى منطقه مؤسسه عالمي تكنولوجيا سماد منطقه الخالديه ساعه عاشر نصف صباح غايه ساعه ظهر منطقه مثلث أحمر مركز إصلاح أم اللولو مركز درك أم اللولو جاروشه الشديفات محول شركه دودين شركه خير شمال ساعه تاسع صباح غايه ساعه ظهر
# 110.67
# تأجيل ميعاد مجدول إعطاء مطعوم كور أعاد خليه أزمه جدول موعد إعطاء مطعوم كور حال جوي تم إرسال رساله نص مواطن موعد جديد
# 110.67
# بدء حمل تطعيم كور معلم 4 مركز عاصمه أعلن وزير تربيه تعليم وزير تعليم عالي بحث علمي دكتور محمد ابوقديس بدء حمل تطعيم كور ثلاثاء معلم 4 مركز عاصمه قال أن حمله بدأ اعتبار خميس قادم محافظه مملكه لافت إلى أن حمله شمل معلم زوجه أو معلم زوج أكد أن حمله ضم معلم قطاع خاص متطرقا إلى أن مديريه قام تجهيز مركز تطعيم محافظ حسب حرف أبجديه أشار إلى أن حمله أتى انطلاق اهتمام وزاره صحه سلام زميل معلم طالب منى إلى أن أعتبر أولويه حتى عاد إلى دراسي أمن أضاف ابوقديس أن وزاره عمل تنسيق وزاره صحه مركز وطني أمن إداره أزمه شدد أن وزاره تطلع إلى عوده تعليم وجاهي عام دراسي قادم سواء مستوى مدرسه أو جامعه ابوقديس أن وزاره تعليم عالي بدأ عيد فطر خطه تطعيم مدرس عضو هيئه تدريس ي عامل جامعه لافت إلى أن خطوه أخرى ذلك خطه تطعيم طالب كليه دعا مواطن إلى ضروره إسراع تسجيل منصه ألقى لقاح وصول إلى صيف أمن لافت إلى أن معلم وصل إلى 150 ألف مدرسه حكومي خاص
# 110.67
# ملك أمر تشكيل لجنه طبي عسكري سلم ملف مستشفى السلط أمر ملك سبت تشكيل لجنه طبي عسكري خدمه طبي ملكيه رئاسه لواء عادل الوهادنه عضو فريق طبي خدمه طبي قيام تحقيق قضيه مستشفى السلط حادث انقطاع أكسجين ضحيه 7 مرضي طلب ملك لجنه تزويد تقرير نتيجه تحقيق
# 110.66
# ارتفاع سعر غاز خبآ أوربا شتاء مروع زال مخافه سيطر صانع قرار اتحاد أوربي وسط تزايد مخافه أن عاش بلد اتحاد شتاء مروع استمرار أزمه ارتفاع سعر غاز مخافه إقدام موسكو إمدادات غاز موقف دوله غزو روسي أوكرانيا من جانب حذر وزاره طاقه بلجيكي أن دوله اتحاد أوربي واجه شتاء قاسي استمرار ارتفاع سعر غاز متسارع بدء أزمه أوكراني أعتبر روسيا مزود أكبر غاز دوله اتحاد شكل نسبه 40 إجمالي احتياج أوربي عام 2021 زال ألمانيا واصل مسعى حثيث تعويض نقص حاصل مخزون غاز لدى حل فصل شتاء بعد فرض عقوبه أوربي روسيا قام موسكو تقليل إمدادات غاز دوله اتحاد أوربي وزير طاقه بلجيكي دير ستراتين تغريد حساب تويتر أن سعر غاز أوربا و جب تثبيت عاجل أن ربط سعر سعر كهرباء رابط تجاري و جب تخلص من De Europese energiemarkt faalt en moet dringend worden hervormd Dit is voor veel gezinnen en bedrijven niet langer houdbaar Elektriciteit wordt even goedkoop als vorig jaar geproduceerd maar aan recordprijzen verkocht Door te hervormen pakken we exuberante overwinsten aan أضاف وزير خلال سنه خمس أو عشر مقبل كان شتاء مروع إذا تم فعل شيء مواجهه ارتفاع سعر غاز و جب اتخاذ قرار مستوى أوربا تثبيت سعر خلال يوم قليل ماضي شهد أوربا ارتفاع سعر كهرباء وصل إلى مستوى قياسي ذلك اعتماد غاز توليد كهرباء في ألمانيا وصل كلف استهلاك كهرباء إلى 1000 كل ميغاواط ساعه بينما وصل فرنسا إلى 1130 شكل زياده قدر ب 10 ضعف دوله عام 2021 جهه مستشار نمساوي كارل نيهامر و جب جنون حدث سوق طاقه فور طالب مستشار فصل سعر كهرباء غاز مشدد أن قرار سعر غاز كهرباء اتحاد أوربي رئيس روسي فلاديمير بوتين آخر منصرم بدأ مدينه برلين ألماني إطفاء كهرباء معلم مبنى تاريخي ذلك جهد وطني بذل توفير طاقه لن تم إضاءه حوال 200 مبني رمزي ليل شمل عمود نصر قصر شارلوتنبورغ مبنى بلديه Some of Berlin s most famous landmarks are looking much darker these summer nights That s because they have turned their lights off as part of Germany s effort to conserve as much energy as possible before winter pic twitter com kzjr1v5sVA
# 110.66
# سلامه ماء محطه أبو صار اتجاه بيرين ملوث أكد ناطق إعلام ي وزاره ماء ري عمر سلامه ل حسني أن ماء خرج محطه تنقيه أبو صار اتجاه وادي بيرين ملوث تم معالجه مواصفه أردني أستخدم غايه زراعي كشف سلامه انتهاء توسع محطه تنقيه أبو صار إنشاء خط ناقل ربط محطه غرب أزرق نقل ماء إلى محطه خرب السمرا شهر أن خرج أي ماء معالجه معالجه محطه أبو صار انتهاء مشروع خضع محطه مراقبه بيئي أوضح أن مشروع حال محطه أبو صار إلى محطه مغلق ضخ ماء صرف صحي عبر أنبوب مغلق محطه رفع غرب أزرق وصول محطه خرب السمرا استكمال آفه مرحله تشغيل محطه أكد أن ماء خرج محطه أبو صار اتجاه وادي بيرين أزرق كشف أخذ عينه مواصفه قياسي مشير إلى أن 190 متر مكعب ماء معالجه محطه صرف صحي أردن غايه استخدام زراعي سلامه أن ضغط عمراني منطقه أبو صار عاصمه عمان زاد حجم ضخ محطه أصبح عمل طاقه عالج آفه كميه وارد إلى لافت إلى أن محطه رفع غرب أزرق قام عمليه معالجه ماء عادم طريق أول ضخ ماء إلى محطه خرب السمرا معالجه تقني عالي سلامه أجاب تساؤل شكوى مواطن رائحه ك ري ه ناتج تجمع ماء محطه أن أي ماء تسرب محطه تنقيه أبو صار منطقه مجاوره ماء معالجه تم ف قد يوم فريق وزاره ماء إشراف وزير ماء عمل فحص لازم تأكد ذلك
# 110.65
# مبادره تشغيل 200 أردني سنوي قطر إعاده تفعيل منصه وطني تشغيل سجل وقع مذكره تفاهم وزاره عمل مجموعه سهيل صناعي قابض قطري تشغيل 200 أردني مجال تدريب مهني صيانه سياره والرياده مهني أمكن أردني راغب عمل قطر تسجيل منصه إلكتروني سجل بدا قطاع خاص قطري استقبال طلب توظيف أردني على تعرف وظيفه مطلوب مجال هندسه فني كهربائي سياره ميكانزم سياره فني كهربائي منزل فني سباكه تكييف تبريد فني صيانه وقع مذكره تفاهم أمس وزير عمل نايف استي رئيس تنفيذي مجموعه سهيل صناعي زياد أبو كلوب حضور سفير قطري عمان شيخ سعود ناصر ال ثاني أشار وزير عمل إلى أن جرى آن تشغيل 9500 أردني عمل جار تشغيل ألف أخرى سوق عمل قطري مؤكد استمراريه تفعيل منصه قطري هدف إلى استقطاب كفاءات أردني تشغيل أوضح أن عمليه اختيار متقدم فرصه عمل جرى شركه قطاع خاص قطر شراكه غرفه صناعه تجاره ما قام وزاره دور تواصل دوله إنشاء منصه جديد غرار منصه قطر تسويق كفاءات أردني سفير قطري عمان شيخ سعود ناصر جاسم ال ثاني أكد أهميه مبادره تشغيل أردني قطاع خاص قطري دافع مشجع شركه قطاع خاص قطري استفاد ه كفاءات أردني
# 110.64
#  سريه قدس توعد احتلال ساعه تاسع وعد ناطق عسكري سريه قدس احتلال صهيوني رد استهداف احتلال برج سكني مدني قطاع غزه أن موعد صاروخ مقاومه سماء تل أبيب ساعه تاسع طائره جيش احتلال إسرائيلي قام تدمير برج هنادي سكني كامل وسط قطاع غزه محاصر وقوع أي إصابه
# 110.64
# مجلس نائب قرر أغلبي ه فصل نائب العجارمه صوت مجلس نائب أحد فصل نائب أسامه العجارمه خلفيه تصريح مؤخر صوت قرار فصل 108 نائب أصل 119 نائب حضرو جلسه خلال جلسه مجلس طارئ عقد رئيس مجلس نائب محامي عبدالمنعم العودات أن شهد وطن يوم ماضي أكد ضروره فرض سياده قانون أجل دفاع أمن استقرار بلد أضاف كلمه أن عضو مجلس مثل طيف شعب أردني أثبت دوره إخلاص بلد أردن ولاء قائد مسيره ملك عبدالله ثاني أشار العودات أن مذكره نيابي قدم إلى مجلس وقع 109 نائب نظر فصل نائب أسامه العجارمه وقت سابق قرر رئيس مجلس نائب محامي عبدالمنعم صالح العودات دعا مجلس انعقاد جلسه طارئ أحد موافق 6 6 2021 تمام ساعه 3 00 ظهر ذلك استجابه مذكره نيابي موقع عضو مجلس نائب تداعي حديث لفظ نائب أسامه العجارمه أمس نظر طلب استقاله مجلس قرر سابع عشرون شهر تجميد عضو نائب العجارمه واحد إساءه مجلس عضو نظام داخلي أعلن نائب العجارمه تقديم استقاله مجلس نائب تاسع عبر موقع تواصل اجتماع ي عبر مذكره سلم إلى نائب نال فريحات دور قدم إلى رئيس مجلس نائب تبنى نائب حسين الحراسيس مذكره نيابي فصل نائب مجمد عضويه أسامه العجارمه
# 110.64
# روسيا أتهم أوكرانيا أن قريب صنع سلاح نووي أدعى روسيا أن أوكرانيا قريب صنع سلاح نووي عباره قنبله قذر أستخدم بلوتونيوم أعتبر عنصر قابل للانشطار أستخدم طاقه صناعه قنبله نووي إنتاج طاقه وفق ذكر وسيله علم روسي وكاله تاس روسي مسؤول روسي أن أوكرانيا تطور سلاح نووي محطه تشرنوبيل نووي أغلق 2000 ما قال حكومه أوكراني أن لدى أي خطه انضمام إلى نادي نووي تخلى سلاح نووي 1994 انهيار اتحاد سوفيتي لكن ما بعد ؛ تحسر قرار تخلي سلاح نووي نقل إلى روسيا تخلى كييف ورق موقع قوه أعظم بين روسيا 1994 تعهد ضمان أمن سبق أن أتهم رئيس روسي فلاديمير بوتين أوكرانيا أن أستخدم خبره سوفيتي صناعه سلاح نووي معروف أن أوكرانيا أعتمد طاقه نووي توليد كهرباء أعتبر محطه زابوريجيا نووي سيطر روسيا جمعه أكبر محطه طاقه نووي أوكرانيا ولد وصل إلى 42 كيلووات ساعه كهرباء مثل خمس إنتاج كهرباء سنوي أوكرانيا
# 110.63
# حلقه جديد برنامج صوت حر اثنين 22 02 2021 حسام غرايبه
# 110.62
# انتهاء عمل لجنه تحقيق ب انقطاع كهرباء منخفض قطبي أخير أعلن وزير طاقه ثروه معدني دكتور صالح الخرابشه أحد انتهاء عمل لجنه تحقيق مستقل شكل تحقيق سبب انقطاع كهرباء منخفض جوي أخير أوضح وزير الخرابشه أن لجنه تسلم توصيه إلى حكومه لحظه مرجح تسليم أسبوع جاري لفت إلى أن بناء توصيه لجنه تم اتخاذ إجراء وزاره أقر مزيد الخرابشه 4 لجنه تحقيق معالجه مشكله انقطاع تيار كهربائي حكومه كلف وزير الخرابشه تشكيل لجنه تحقيق مستقل معرفه سبب انقطاع تيار كهربائي المنخفظ قطبي أثر مملكه منصرم اتفاق أن أستكمل لجنه تحقيق تقدم توصيه أسبوع أقصى تقدير ؛ تحديد مسؤوليه معرفه وجه تقصير أن وجد اتخاذ إجراء إداري قانوني حق مقصر مسؤوليه قانوني
# 110.62
# لواء إمارات ي أحمد الريسي رئيس إنتربول وسط مخافه حقوق ي أنتخب تركيا لواء إمارات ي أحمد الريسي رئيس منظمه شرطه دولي إنتربول وسط مخافه حقوق ي عبر منظمه هيومن رايتس ووتش HRW مركز خليج حق إنسان وفق منظمه HRW إن انتخاب رئاسه إنتربول أفتقر رقابه شفافيه أن إنتربول وفر أي معلومه علني مرشح منصب رئاسه وجد إجراء تدقيق مرشح دوله عضو HRW حذر قبيل يوم انتخاب الريسي قائل أن وصول منصب دق ناقوس خطر شأن حق إنسان كون شغل منصب مفتش عام جهاز أمن إمارات ي سجل طويل انتهى ك وصف ب سيء سمعه أنتخب إنتربول أسبوع رئيس جدي ترشيح لواء أحمد ناصر الريسي مسؤول وزاره داخلي إماره جهاز أمني سيء سمعه منصب دق ناقوس خطر شأن حق إنسان pic twitter com XjyiaKtxqx أعتبر خالد إبراهيم مدير خليج حق إنسان رئاسه الريسي إنتربول محاوله إمارات ي شراء احترام دولي تلميع سجل حقوق ي مزري أن أظهر أن دوله عضو إنتربول مكترث أو قلق سجل اضطهاد إماره منتقد سلمي جانب الريسي أن انتخاب إنجاز عرب ثمر جهد قياده إمارات ي امتداد كون بلد أكثر دوله أمان عالم صفه رئيس ل INTERPOL HQ حرص أن منظمه أكثر شفافيه تنوع حزم أداء رساله ضمان أمن سلام جميع سر انتخاب رئيس إنتربول هذا منصب أشرف مسيره مهني عبر خدمه مواطن نحو عالم نيابه دوله إماره
# 110.62
# 44 قتيل أكثر مصاب دافع احتفال يهودي لقي 44 أقل مصرع أصاب مئه دافع جماهيري ليل خميس جمعه احتفال يهودي متدين جبل الجرمق قرب صفد قدر مشارك احتفال 100 ألف أفاد تقرير أن حادث وقع نتيجه التدافع تزاحم شديد احتفال ؛ ما أشار إلى انهيار جزء مدرج أقام احتفال يوم لاغي بعومر يهودي لاغي بعومر مناسبه ديني شعب رد ذكر تورى ه أو كتب عالم تورى ه يهودي لاحق بدا ذكر أظهر كتب تفسير راوند متأخر أشار إلى كون تاريخ انتقال ي راوند إلى أخرى قال أيض أن ذكرى مقتل تلميذ أتباع حاخام عقيب فتره 50 136 ميلاد ذكر طاقم تابع نجم داود أحمر أن قدم إسعاف نحو 103 مصاب بين 38 حال وصف حرج أوضح أن 18 مصاب حال خطير و2 أصاب جرح متوسط و39 وصف إصابه طفيف تم استدعاء 6 مروحيه عسكري إجلاء مصاب حسب قناه عام إسرائيلي كان 11 أشار إلى وجود عالق أن عشرات عائله تمكن وصول إلى أبناء نقل سياره إسعاف 80 مصاب موقع حادث إلى مستشفى قريب إذ نقل 45 مصاب إلى صفد 24 إلى نهار ي و17 إلى طبري و5 إلى حيفا حسب موقع إلكتروني صحيفه يديعوت أحرونوت ؛ دعا منظم احتفال قوه شرطه مشارك إلى تفرق مغادره مكان ما أغلق طريق مؤدي إلى جبل أمام حركه مرور أوقف شرطه عشرات حافل طريق إلى موقع احتفال طالب مغادره وسط ازدحام مرور ي شديد أظهر تحقيق أول شرطه أن محتفل أنزلق أحد مدرج أمر أد إلى وقوع مئه مدرج تم سحق ضحيه قدم وسط تزاحم والتدافع وصف رئيس حكومه احتلال بنيامين نتانياهو حادث تويتر أن كارثه كبير بلغ محتفل جبل الجرمق 100 ألف شخص أكبر احتشاد بدء انتشار فيروس كور إذ صادف لاغي بعومر ليل خميس ذلك أول 13 عام جمع محتفل ضريح حاخام شمعون بار يوحاي موقع ميرون احتفال سنوي شمل صلاه رقص طويل ليل
# 110.61
# مجمع لغه عربي أطلق مسابقه لغه شراكه مبادره ض  أطلق مجمع لغه عربي أردني أول تعاون مبادره ض أحد مبادره مؤسس ولي عهد مسابقه لغه هادف إلى تنميه قدر طفل تعبير لغه عربي سليم ممارسه حياه مسيره تعليمي أشتمل مسابقه كما جاء بيان مجمع جائزه متعدد دعم عربي ترسيخ نفس نشء تمثل محور عده لغه عبر نفس و لغه تحدث وجه نظر و لغه شرح مشكله أو أي محور مشابه مذكور أعلى أشار بيان إلى أن مسابقه أستهدف فئه عمر ي 6 إلى 18 سنه أشترط إرسال فيديو مده 3 دقيقه أو ماده مكتوب واقع 100 كلمه تم استلام ماده رابط نموذج جوجل Google آتي تم تحكيم ماده اختيار أفضل مشارك فوز جائزه مسابقه إشراف محكم مختص آخر موعد استلام مشاركه ثلاث أيار سوف أعلن نتيجه منتصف مقبل أضاف بيان أن تم إعلان تفصيل آفه مسابقه جائزه موقع مجمع إلكتروني موقع مبادره ض inarabic cpf jo صفحه مؤسس ولي عهد مجمع موقع تواصل اجتماع ي الفيسبوك
# 110.6
# تسجيل 17 وفاه و604 إصابه جديد فيروس كور سجل 17 وفاه و604 إصابه جديد أردن فيروس كور حسب موجز صادر رئاسه وزير وزاره صحه أربعاء ذلك أرتفع إجمالي وفاه إلى 9489 إجمالي حاله إصابه مملكه إلى 737888 حال ما بلغ حاله نشط حالي 10276 حال أشار االموجز إعلام ي أن نسب فحص إيجابي إجمالي فحص المخبريه كشف فيروس كور بلغ 2 8 مئه أن تم إجراء 22 814 فحص مخبريا أصبح إجمالي فحص 22814 فحص بلغ حاله أدخل إلى مستشفى 64 حاله ما غادر 63 حال بينما بلغ إجمالي حاله مؤكد تلقى علاج مستشفى 552 حال بلغ حاله شفاء أعزل منزل ي مستشفى 937 حال وصل إجمالي حاله شفاء إلى 718123 حال
# 110.6
# صحف ي ناشر موقع إلكتروني أعتصم رفض تعديل هيئه إعلام أكد صحف ي ناشر موقع إلكتروني رفض تعديل أقترح هيئه إعلام متعلق نظام بث إذاعي تلفزيوني ترخيص موقع إلكتروني رسم معتبرينها ممارسه تضييق حريه عام إعلام دعا معتصم وقف احتجاج أمام مبني نقابه صحف ي أردني إلى سحب تعديل تشكيل مجلس إداره هيئه إعلام رسم سياسه إعلام ي مشاوره نقابه صحف ي أمر متعلق تطوير مهنه تنظيم عمل آفه مؤسسه إعلام رفع مشارك يفطه طالب استقاله مدير هيئه إعلام طارق أبو راغب سحب نظام ثلاث إطلاق حريه صحف ي أبرز تعديل رفع هيئه إعلام إلى حكومه شمل آتي إعاده تعريف بث عبر إنترنت شمل تعريف تالي إرسال برنامج عمل إذاعي تلفزيوني واسطه تقنيه مختلف حيث تمكن جمهور استقبال عبر بروتوكول إنترنت استيفاء سبع دولار تجديد رخصه موقع إلكتروني بدل دينار سبع دولار فرض رسم قدر 2500 ثلاث ألف وخمسمئه دولار منح رخصه بث برنامج إذاعي تلفزيوني عبر إنترنت ألقى صحف ي باسل العكور كلمه صحف ي عامل إعلام إلكتروني حمل حكومه شر الخصاونه مسؤول تعديل تضييق حريه داعي إلى فتح حوار مؤسسه إعلام ي دعا مشاركه عاصفه إلكتروني مقرر ساعه ثامن موقع تواصل اجتماع ي إلى جانب عديد فعاليات نشاط أن حكومه أراد إنهاء إعلام مستقل خنق إعلام كاف وسيله
# 110.6
# ضبط 35 حال إشعاع عبر معبر عقبه نويبع 2010 آذار 2022 كشف مدير أمن نووي هيئه تنظيم قطاع طاقه معادن مهندس لؤي الكسواني خميس ل حسني ضبط 35 حال إشعاع عبر معبر راكب عقبه نويبع أردن مصر ذلك 2010 غايه بدايه آذار جاري 2022 تم إعاده إلى مصدر منع دخول إلى مملكه شحنه حديد عطر أشار الكسواني أن هيئه 88 جهاز رقابه إشعاع معبر مملكه برى ب حريه جوي رقابه بضاعه غذاء مبين أن فحص إشعاع ي غطى ماده نسبه 100 ؤخذ فحص صوره عشوائي مضيف أن أول مطار شرق أوسط وفر جهاز كشف إشعاع ي مطار ملك حسين دولي عقبه الكسواني معبر راكب عقبه نويبع تم فحص شاحنه مركبه باص قادم مغادره والترانزيت ثنى عبور جهاز كشف إشعاع ي ثابت حديث متطور كشف شعاع جاما جسيم نيوترون منع اتجار مشروع ماده نووي ماده إشعاع ي أخرى تم فحص مسافر جهاز كشف إشعاع ي Walk throw محطه راكب عقبه معبر جنوب وادي عرب منع اتجار مشروع ماده نووي ماده إشعاع ي أخرى جدر إشاره أن 2004 شهد تركيب أول جهاز كشف إشعاع ي مملكه تزايد نشاط نشاط تجاره خرده بعيد غزو عراق 2003 أظهر إحصاء شركه عقبه إداره تشغيل ميناء رحله راكب شاحنه دخل عقبه عام 2013 حتى 2021 أظهر إحصاء ي أن رحله ب حريه أردن مصر عام بلغ 588 رحله خلال نقل 230 ألف مسافر من أكثر 170 ألف قادم مملكه
# 110.59
# تعذر رؤيه هلال رمضان جمعه فلكي قال أمين سر جمعيه فلكي أردني عضو مركز فلك دولي سمه ذياب أن تنبؤ دراسه فلكي أشار إلى تمكن رؤيه هلال رمضان جمعه فلكي وفق توقع إعلان أن سبت المتمم شهر شعبان يوم أحد أول يوم شهر رمضان مبارك أشار ذياب حسني إلى شكل محاق تولد جمعه دوله عالم إسلامي أن هلال شهر رمضان تولد جمعه تمكن فلكي رصد عين مجرد أو عبر تلسكوب سياق متصل لفت ذياب إلى أهميه ضبط مسأله شهاده رؤيه هلال حيث توافق علم موضح أن فلك قدم ل حساب رياضي مسبق عن حدث بناء حساب دقيقه ناموس كون حركه فلك قدم ل معلومه أثبت رؤيه

# %%
# # Step 1: Change data type
# embeddings = np.array([embedding for embedding in embeddings]).astype("float32")

# # Step 2: Instantiate the index
# index = faiss.IndexFlatL2(embeddings.shape[1])

# # Step 3: Pass the index to IndexIDMap
# index = faiss.IndexIDMap(index)

# # Step 4: Add vectors and their IDs
# index.add_with_ids(embeddings, df.id.values)

# # Retrieve the 10 nearest neighbours
# D, I = index.search(np.array([embeddings[5415]]), k=10)

# %% [markdown]
# ## References

# %% [markdown]
# - https://towardsdatascience.com/how-to-build-a-semantic-search-engine-with-transformers-and-faiss-dcbea307a0e8
